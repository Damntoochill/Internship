# %% [markdown]
# <a href="https://colab.research.google.com/github/Damntoochill/Internship/blob/master/LSTM_KF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pykalman import KalmanFilter

import keras
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation, Embedding
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ##Preprocess Train and Test Data using Kalman Filtering

# %%
# read training data 
train_df = pd.read_csv('PM_train.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
for cols in train_df.columns:
    if cols == 'id':
        continue;
    if cols == 'cycle':
        continue;
    else:
        kf = KalmanFilter(transition_matrices = [1],
                      observation_matrices = [1],
                      initial_state_mean = train_df[cols].values[0],
                      initial_state_covariance = 1,
                      observation_covariance=1,
                      transition_covariance=.01)
        state_means,_ = kf.filter(train_df[cols].values)
        train_df[cols] = state_means.flatten()

# %%
# read test data
test_df = pd.read_csv('PM_test.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
for cols in test_df.columns:
    if cols == 'id':
        continue;
    if cols == 'cycle':
        continue;
    else:
        kf = KalmanFilter(transition_matrices = [1],
                      observation_matrices = [1],
                      initial_state_mean = test_df[cols].values[0],
                      initial_state_covariance = 1,
                      observation_covariance=1,
                      transition_covariance=.01)
        state_means,_ = kf.filter(test_df[cols].values)
        test_df[cols] = state_means.flatten()

# %%
# read ground truth data
truth_df = pd.read_csv('PM_truth.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %%
train_df = train_df.sort_values(['id','cycle'])
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...     s18    s19        s20        s21
# 0   1      1 -0.000700 -0.000400  ...  2388.0  100.0  39.060000  23.419000
# 1   1      2  0.000178 -0.000366  ...  2388.0  100.0  39.039735  23.420554
# 2   1      3 -0.000977 -0.000194  ...  2388.0  100.0  39.016581  23.400853
# 3   1      4 -0.000623 -0.000153  ...  2388.0  100.0  38.987712  23.395156
# 4   1      5 -0.000854 -0.000162  ...  2388.0  100.0  38.971815  23.396831
#
# [5 rows x 26 columns]

# %% [markdown]
# ##Generate True Values for Train Data

# %%
# Data Labeling - generate column RUL
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...    s19        s20        s21  RUL
# 0   1      1 -0.000700 -0.000400  ...  100.0  39.060000  23.419000  191
# 1   1      2  0.000178 -0.000366  ...  100.0  39.039735  23.420554  190
# 2   1      3 -0.000977 -0.000194  ...  100.0  39.016581  23.400853  189
# 3   1      4 -0.000623 -0.000153  ...  100.0  38.987712  23.395156  188
# 4   1      5 -0.000854 -0.000162  ...  100.0  38.971815  23.396831  187
#
# [5 rows x 27 columns]

# %%
# generate label columns for training data
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...        s21  RUL  label1  label2
# 0   1      1 -0.000700 -0.000400  ...  23.419000  191       0       0
# 1   1      2  0.000178 -0.000366  ...  23.420554  190       0       0
# 2   1      3 -0.000977 -0.000194  ...  23.400853  189       0       0
# 3   1      4 -0.000623 -0.000153  ...  23.395156  188       0       0
# 4   1      5 -0.000854 -0.000162  ...  23.396831  187       0       0
#
# [5 rows x 29 columns]

# %% [markdown]
# ##Normalize Train and Test Data

# %%
# MinMax normalization
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  RUL  label1  label2  cycle_norm
# 0   1      1  0.368542  0.000000  ...  191       0       0     0.00000
# 1   1      2  0.606362  0.045503  ...  190       0       0     0.00277
# 2   1      3  0.293440  0.277092  ...  189       0       0     0.00554
# 3   1      4  0.389455  0.332429  ...  188       0       0     0.00831
# 4   1      5  0.326762  0.321014  ...  187       0       0     0.01108
#
# [5 rows x 30 columns]

# %%
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  1.181006  0.943062  ...  0.0  0.637261  0.785538     0.00000
# 1   1      2  0.723659  0.670047  ...  0.0  0.718589  0.801113     0.00277
# 2   1      3  0.701909  0.670968  ...  0.0  0.783034  0.825428     0.00554
# 3   1      4  0.911938  0.643051  ...  0.0  0.796756  0.817104     0.00831
# 4   1      5  0.916529  0.624173  ...  0.0  0.803308  0.829623     0.01108
#
# [5 rows x 27 columns]

# %% [markdown]
# ##Generate True Values for Test Data

# %%
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# %%
# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...       s20       s21  cycle_norm  RUL
# 0   1      1  1.181006  0.943062  ...  0.637261  0.785538     0.00000  142
# 1   1      2  0.723659  0.670047  ...  0.718589  0.801113     0.00277  141
# 2   1      3  0.701909  0.670968  ...  0.783034  0.825428     0.00554  140
# 3   1      4  0.911938  0.643051  ...  0.796756  0.817104     0.00831  139
# 4   1      5  0.916529  0.624173  ...  0.803308  0.829623     0.01108  138
#
# [5 rows x 28 columns]

# %%
# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  cycle_norm  RUL  label1  label2
# 0   1      1  1.181006  0.943062  ...     0.00000  142       0       0
# 1   1      2  0.723659  0.670047  ...     0.00277  141       0       0
# 2   1      3  0.701909  0.670968  ...     0.00554  140       0       0
# 3   1      4  0.911938  0.643051  ...     0.00831  139       0       0
# 4   1      5  0.916529  0.624173  ...     0.01108  138       0       0
#
# [5 rows x 30 columns]

# %%
# pick a large window size of 50 cycles
sequence_length = 50

# %% [markdown]
# ##Train and Test Sequences

# %%
# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which
    are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :]

# %%
# pick the feature columns 
# sensor_cols = ['s' + str(i) for i in range(1,22)]
# sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sensor_cols = ['s2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']
sequence_cols = ['setting1', 'setting2', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# %%
# generator for the sequences
seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# %%
# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
seq_array.shape
# Out:
# (15631, 50, 17)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_array = id_df[label].values
    num_elements = data_array.shape[0]
    return data_array[seq_length:num_elements, :]

# %%
# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]
label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (15631, 1)

# %%
from keras.optimizers import Adam, RMSprop
from keras.layers import Input, Reshape, Dropout
from keras import Model

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()
model.add(LSTM(
         units=100,
         return_sequences=True,
         input_shape=(sequence_length, nb_features)))
model.add(Dropout(0.4))
model.add(LSTM(
          units=100,
          return_sequences=False))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='relu'))
model.add(Activation("relu"))
model.compile(loss="mse", optimizer="rmsprop", metrics=['mse'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0703 08:19:21.744121 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0703 08:19:21.769084 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0703 08:19:21.772931 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0703 08:19:22.012079 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0703 08:19:22.022379 139736809940864 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0703 08:19:22.273673 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 100)           47200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 100)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 127,701
# Trainable params: 127,701
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
# fit the network
hist = model.fit(seq_array, label_array, epochs=50, batch_size=200, validation_split=0.05, verbose=1,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto')])
# Out:
# W0703 08:19:32.048299 139736809940864 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0703 08:19:33.287771 139736809940864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 14849 samples, validate on 782 samples
# Epoch 1/40
# 14849/14849 [==============================] - 30s 2ms/step - loss: 7999.6748 - mean_squared_error: 7999.6748 - val_loss: 7198.6810 - val_mean_squared_error: 7198.6810
# Epoch 2/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 6930.5905 - mean_squared_error: 6930.5905 - val_loss: 6330.1322 - val_mean_squared_error: 6330.1322
# Epoch 3/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 6108.7581 - mean_squared_error: 6108.7581 - val_loss: 5576.6484 - val_mean_squared_error: 5576.6484
# Epoch 4/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 5404.9514 - mean_squared_error: 5404.9514 - val_loss: 4927.0271 - val_mean_squared_error: 4927.0271
# Epoch 5/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 4795.1824 - mean_squared_error: 4795.1824 - val_loss: 4382.5957 - val_mean_squared_error: 4382.5957
# Epoch 6/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 4317.8702 - mean_squared_error: 4317.8702 - val_loss: 3941.0455 - val_mean_squared_error: 3941.0455
# Epoch 7/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 3921.3318 - mean_squared_error: 3921.3318 - val_loss: 3600.9846 - val_mean_squared_error: 3600.9846
# Epoch 8/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 3630.3564 - mean_squared_error: 3630.3564 - val_loss: 3366.4348 - val_mean_squared_error: 3366.4348
# Epoch 9/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 3444.7324 - mean_squared_error: 3444.7324 - val_loss: 3266.0657 - val_mean_squared_error: 3266.0657
# Epoch 10/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 2821.6198 - mean_squared_error: 2821.6198 - val_loss: 2480.8937 - val_mean_squared_error: 2480.8937
# Epoch 11/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 2194.7438 - mean_squared_error: 2194.7438 - val_loss: 1880.9447 - val_mean_squared_error: 1880.9447
# Epoch 12/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1894.9281 - mean_squared_error: 1894.9281 - val_loss: 1588.6912 - val_mean_squared_error: 1588.6912
# Epoch 13/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1662.0870 - mean_squared_error: 1662.0870 - val_loss: 1475.7327 - val_mean_squared_error: 1475.7327
# Epoch 14/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1466.4830 - mean_squared_error: 1466.4830 - val_loss: 1694.9054 - val_mean_squared_error: 1694.9054
# Epoch 15/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1285.0855 - mean_squared_error: 1285.0855 - val_loss: 1175.1557 - val_mean_squared_error: 1175.1557
# Epoch 16/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1156.0878 - mean_squared_error: 1156.0878 - val_loss: 1018.8125 - val_mean_squared_error: 1018.8125
# Epoch 17/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 1050.9901 - mean_squared_error: 1050.9901 - val_loss: 1084.7849 - val_mean_squared_error: 1084.7849
# Epoch 18/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 966.7825 - mean_squared_error: 966.7825 - val_loss: 955.1774 - val_mean_squared_error: 955.1774
# Epoch 19/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 932.0021 - mean_squared_error: 932.0021 - val_loss: 870.3247 - val_mean_squared_error: 870.3247
# Epoch 20/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 861.8225 - mean_squared_error: 861.8225 - val_loss: 1081.3070 - val_mean_squared_error: 1081.3070
# Epoch 21/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 822.4702 - mean_squared_error: 822.4702 - val_loss: 1036.1476 - val_mean_squared_error: 1036.1476
# Epoch 22/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 799.0681 - mean_squared_error: 799.0681 - val_loss: 857.1123 - val_mean_squared_error: 857.1123
# Epoch 23/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 769.1308 - mean_squared_error: 769.1308 - val_loss: 973.7570 - val_mean_squared_error: 973.7570
# Epoch 24/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 746.2492 - mean_squared_error: 746.2492 - val_loss: 874.9822 - val_mean_squared_error: 874.9822
# Epoch 25/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 716.9704 - mean_squared_error: 716.9704 - val_loss: 1394.4307 - val_mean_squared_error: 1394.4307
# Epoch 26/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 702.0555 - mean_squared_error: 702.0555 - val_loss: 807.1157 - val_mean_squared_error: 807.1157
# Epoch 27/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 679.4954 - mean_squared_error: 679.4954 - val_loss: 846.9863 - val_mean_squared_error: 846.9863
# Epoch 28/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 663.1226 - mean_squared_error: 663.1226 - val_loss: 1086.7786 - val_mean_squared_error: 1086.7786
# Epoch 29/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 680.1142 - mean_squared_error: 680.1142 - val_loss: 1058.3877 - val_mean_squared_error: 1058.3877
# Epoch 30/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 647.7520 - mean_squared_error: 647.7520 - val_loss: 1215.9074 - val_mean_squared_error: 1215.9074
# Epoch 31/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 626.5442 - mean_squared_error: 626.5442 - val_loss: 1029.6980 - val_mean_squared_error: 1029.6980
# Epoch 32/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 607.0669 - mean_squared_error: 607.0669 - val_loss: 856.7184 - val_mean_squared_error: 856.7184
# Epoch 33/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 600.1850 - mean_squared_error: 600.1850 - val_loss: 963.4139 - val_mean_squared_error: 963.4139
# Epoch 34/40
# 14849/14849 [==============================] - 31s 2ms/step - loss: 581.0682 - mean_squared_error: 581.0682 - val_loss: 867.0116 - val_mean_squared_error: 867.0116
# Epoch 35/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 561.6662 - mean_squared_error: 561.6662 - val_loss: 1028.6110 - val_mean_squared_error: 1028.6110
# Epoch 36/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 545.5185 - mean_squared_error: 545.5185 - val_loss: 750.9094 - val_mean_squared_error: 750.9094
# Epoch 37/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 537.2752 - mean_squared_error: 537.2752 - val_loss: 879.1522 - val_mean_squared_error: 879.1522
# Epoch 38/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 515.6874 - mean_squared_error: 515.6874 - val_loss: 859.3607 - val_mean_squared_error: 859.3607
# Epoch 39/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 492.3338 - mean_squared_error: 492.3338 - val_loss: 1647.0982 - val_mean_squared_error: 1647.0982
# Epoch 40/40
# 14849/14849 [==============================] - 28s 2ms/step - loss: 493.0660 - mean_squared_error: 493.0660 - val_loss: 673.9790 - val_mean_squared_error: 673.9790
# CPU times: user 33min 39s, sys: 2min, total: 35min 40s
# Wall time: 18min 50s

# %%
plt.plot(hist.history['mean_squared_error'])
plt.plot(hist.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('Mean Squared Error')
plt.xlabel('# Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('MSE: {}'.format(scores[1]))
# Out:
# 15631/15631 [==============================] - 7s 430us/step
# MSE: 582.0848081318585

# %%
seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
seq_array_test_last.shape
# Out:
# (93, 50, 17)

# %%
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]

# %%
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
label_array_test_last.shape
# Out:
# (93, 1)

# %%
print(seq_array_test_last.shape)
print(label_array_test_last.shape)
# Out:
# (93, 50, 17)
# (93, 1)

# %%
# test metrics
scores_test = model.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
print('MSE: {}'.format(scores_test[1]))
# Out:
# MSE: 454.3958471154654

# %%
results_df = pd.DataFrame([[scores_test[1]],],
                         columns = ['MSE'],
                         index = ['LSTM'])
results_df
# Out:
#              MSE
# LSTM  454.395847

# %%
y_pred_test = model.predict(seq_array_test_last, verbose=0)

import matplotlib.pyplot as plt2

plt2.plot(y_pred_test, color='red', label='Prediction')
plt2.plot(label_array_test_last, color='blue', label='Ground Truth')
plt2.legend(loc='upper left')
plt2.show()
