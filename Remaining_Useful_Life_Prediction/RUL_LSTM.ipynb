# %% [markdown]
# <a href="https://colab.research.google.com/github/Damntoochill/Internship/blob/master/RUL_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import keras
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation, Embedding
# Out:
# Using TensorFlow backend.

# %%
# read training data 
train_df = pd.read_csv('PM_train.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
# read test data
test_df = pd.read_csv('PM_test.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
# read ground truth data
truth_df = pd.read_csv('PM_truth.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %%
train_df = train_df.sort_values(['id','cycle'])
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3  ...  s17   s18    s19    s20      s21
# 0   1      1   -0.0007   -0.0004     100.0  ...  392  2388  100.0  39.06  23.4190
# 1   1      2    0.0019   -0.0003     100.0  ...  392  2388  100.0  39.00  23.4236
# 2   1      3   -0.0043    0.0003     100.0  ...  390  2388  100.0  38.95  23.3442
# 3   1      4    0.0007    0.0000     100.0  ...  392  2388  100.0  38.88  23.3739
# 4   1      5   -0.0019   -0.0002     100.0  ...  393  2388  100.0  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
# Data Labeling - generate column RUL
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3  ...   s18    s19    s20      s21  RUL
# 0   1      1   -0.0007   -0.0004     100.0  ...  2388  100.0  39.06  23.4190  191
# 1   1      2    0.0019   -0.0003     100.0  ...  2388  100.0  39.00  23.4236  190
# 2   1      3   -0.0043    0.0003     100.0  ...  2388  100.0  38.95  23.3442  189
# 3   1      4    0.0007    0.0000     100.0  ...  2388  100.0  38.88  23.3739  188
# 4   1      5   -0.0019   -0.0002     100.0  ...  2388  100.0  38.90  23.4044  187
#
# [5 rows x 27 columns]

# %%
# generate label columns for training data
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3  ...    s20      s21  RUL  label1  label2
# 0   1      1   -0.0007   -0.0004     100.0  ...  39.06  23.4190  191       0       0
# 1   1      2    0.0019   -0.0003     100.0  ...  39.00  23.4236  190       0       0
# 2   1      3   -0.0043    0.0003     100.0  ...  38.95  23.3442  189       0       0
# 3   1      4    0.0007    0.0000     100.0  ...  38.88  23.3739  188       0       0
# 4   1      5   -0.0019   -0.0002     100.0  ...  38.90  23.4044  187       0       0
#
# [5 rows x 29 columns]

# %%
# MinMax normalization
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  RUL  label1  label2  cycle_norm
# 0   1      1  0.459770  0.166667  ...  191       0       0     0.00000
# 1   1      2  0.609195  0.250000  ...  190       0       0     0.00277
# 2   1      3  0.252874  0.750000  ...  189       0       0     0.00554
# 3   1      4  0.540230  0.500000  ...  188       0       0     0.00831
# 4   1      5  0.390805  0.333333  ...  187       0       0     0.01108
#
# [5 rows x 30 columns]

# %%
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.632184  0.750000  ...  0.0  0.558140  0.661834     0.00000
# 1   1      2  0.344828  0.250000  ...  0.0  0.682171  0.686827     0.00277
# 2   1      3  0.517241  0.583333  ...  0.0  0.728682  0.721348     0.00554
# 3   1      4  0.741379  0.500000  ...  0.0  0.666667  0.662110     0.00831
# 4   1      5  0.580460  0.500000  ...  0.0  0.658915  0.716377     0.01108
#
# [5 rows x 27 columns]

# %%
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# %%
# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...       s20       s21  cycle_norm  RUL
# 0   1      1  0.632184  0.750000  ...  0.558140  0.661834     0.00000  142
# 1   1      2  0.344828  0.250000  ...  0.682171  0.686827     0.00277  141
# 2   1      3  0.517241  0.583333  ...  0.728682  0.721348     0.00554  140
# 3   1      4  0.741379  0.500000  ...  0.666667  0.662110     0.00831  139
# 4   1      5  0.580460  0.500000  ...  0.658915  0.716377     0.01108  138
#
# [5 rows x 28 columns]

# %%
# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...  cycle_norm  RUL  label1  label2
# 0   1      1  0.632184  0.750000  ...     0.00000  142       0       0
# 1   1      2  0.344828  0.250000  ...     0.00277  141       0       0
# 2   1      3  0.517241  0.583333  ...     0.00554  140       0       0
# 3   1      4  0.741379  0.500000  ...     0.00831  139       0       0
# 4   1      5  0.580460  0.500000  ...     0.01108  138       0       0
#
# [5 rows x 30 columns]

# %%
# pick a large window size of 50 cycles
sequence_length = 50

# %%
# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which
    are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :]

# %%
# pick the feature columns 
# sensor_cols = ['s' + str(i) for i in range(1,22)]
# sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sensor_cols = ['s2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']
sequence_cols = ['setting1', 'setting2', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# %%
# generator for the sequences
seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# %%
# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
seq_array.shape
# Out:
# (15631, 50, 17)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_array = id_df[label].values
    num_elements = data_array.shape[0]
    return data_array[seq_length:num_elements, :]

# %%
# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]
label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (15631, 1)

# %%
from keras.optimizers import Adam, RMSprop
from keras.layers import Input, Reshape, Dropout
from keras import Model

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()
model.add(LSTM(
         units=100,
         return_sequences=True,
         input_shape=(sequence_length, nb_features)))
model.add(Dropout(0.4))
model.add(LSTM(
          units=100,
          return_sequences=False))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='relu'))
model.add(Activation("relu"))
model.compile(loss="mse", optimizer="rmsprop", metrics=['mse'])

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 100)           47200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 100)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 127,701
# Trainable params: 127,701
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
# fit the network
hist = model.fit(seq_array, label_array, epochs=40, batch_size=200, validation_split=0.05, verbose=1,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto')])
# Out:
# W0703 08:50:24.775444 139863304894336 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0703 08:50:26.223400 139863304894336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 14849 samples, validate on 782 samples
# Epoch 1/40
# 14849/14849 [==============================] - 20s 1ms/step - loss: 8214.1214 - mean_squared_error: 8214.1214 - val_loss: 7427.9821 - val_mean_squared_error: 7427.9821
# Epoch 2/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 7153.2036 - mean_squared_error: 7153.2036 - val_loss: 6545.5770 - val_mean_squared_error: 6545.5770
# Epoch 3/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 6319.7637 - mean_squared_error: 6319.7637 - val_loss: 5767.8212 - val_mean_squared_error: 5767.8212
# Epoch 4/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 5586.3875 - mean_squared_error: 5586.3875 - val_loss: 5098.3656 - val_mean_squared_error: 5098.3656
# Epoch 5/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 4960.8061 - mean_squared_error: 4960.8061 - val_loss: 4524.4050 - val_mean_squared_error: 4524.4050
# Epoch 6/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 4448.2471 - mean_squared_error: 4448.2471 - val_loss: 4062.1409 - val_mean_squared_error: 4062.1409
# Epoch 7/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 4038.5760 - mean_squared_error: 4038.5760 - val_loss: 3699.7381 - val_mean_squared_error: 3699.7381
# Epoch 8/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 3710.2089 - mean_squared_error: 3710.2089 - val_loss: 3433.6477 - val_mean_squared_error: 3433.6477
# Epoch 9/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 3495.5342 - mean_squared_error: 3495.5342 - val_loss: 3270.5697 - val_mean_squared_error: 3270.5697
# Epoch 10/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 3353.6943 - mean_squared_error: 3353.6943 - val_loss: 2665.8010 - val_mean_squared_error: 2665.8010
# Epoch 11/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 2447.6939 - mean_squared_error: 2447.6939 - val_loss: 2195.9398 - val_mean_squared_error: 2195.9398
# Epoch 12/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 2042.1747 - mean_squared_error: 2042.1747 - val_loss: 1791.2508 - val_mean_squared_error: 1791.2508
# Epoch 13/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1733.1745 - mean_squared_error: 1733.1745 - val_loss: 1464.3867 - val_mean_squared_error: 1464.3867
# Epoch 14/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1522.1563 - mean_squared_error: 1522.1563 - val_loss: 1290.6586 - val_mean_squared_error: 1290.6586
# Epoch 15/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1370.7943 - mean_squared_error: 1370.7943 - val_loss: 1075.6361 - val_mean_squared_error: 1075.6361
# Epoch 16/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1235.0244 - mean_squared_error: 1235.0244 - val_loss: 987.0878 - val_mean_squared_error: 987.0878
# Epoch 17/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1124.6430 - mean_squared_error: 1124.6430 - val_loss: 1142.3915 - val_mean_squared_error: 1142.3915
# Epoch 18/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 1049.9829 - mean_squared_error: 1049.9829 - val_loss: 836.8810 - val_mean_squared_error: 836.8810
# Epoch 19/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 982.3591 - mean_squared_error: 982.3591 - val_loss: 869.4824 - val_mean_squared_error: 869.4824
# Epoch 20/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 958.8205 - mean_squared_error: 958.8205 - val_loss: 930.5233 - val_mean_squared_error: 930.5233
# Epoch 21/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 899.1462 - mean_squared_error: 899.1462 - val_loss: 851.1436 - val_mean_squared_error: 851.1436
# Epoch 22/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 865.7181 - mean_squared_error: 865.7181 - val_loss: 941.9197 - val_mean_squared_error: 941.9197
# Epoch 23/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 850.8971 - mean_squared_error: 850.8971 - val_loss: 819.5255 - val_mean_squared_error: 819.5255
# Epoch 24/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 827.2588 - mean_squared_error: 827.2588 - val_loss: 919.6177 - val_mean_squared_error: 919.6177
# Epoch 25/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 815.6076 - mean_squared_error: 815.6076 - val_loss: 878.8913 - val_mean_squared_error: 878.8913
# Epoch 26/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 774.6898 - mean_squared_error: 774.6898 - val_loss: 979.6210 - val_mean_squared_error: 979.6210
# Epoch 27/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 763.9652 - mean_squared_error: 763.9652 - val_loss: 1111.2882 - val_mean_squared_error: 1111.2882
# Epoch 28/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 726.7476 - mean_squared_error: 726.7476 - val_loss: 943.8468 - val_mean_squared_error: 943.8468
# Epoch 29/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 713.6429 - mean_squared_error: 713.6429 - val_loss: 973.5355 - val_mean_squared_error: 973.5355
# Epoch 30/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 679.6653 - mean_squared_error: 679.6653 - val_loss: 1022.4425 - val_mean_squared_error: 1022.4425
# Epoch 31/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 667.5700 - mean_squared_error: 667.5700 - val_loss: 796.1101 - val_mean_squared_error: 796.1101
# Epoch 32/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 642.0794 - mean_squared_error: 642.0794 - val_loss: 1020.8841 - val_mean_squared_error: 1020.8841
# Epoch 33/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 625.6851 - mean_squared_error: 625.6851 - val_loss: 989.4799 - val_mean_squared_error: 989.4799
# Epoch 34/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 622.8737 - mean_squared_error: 622.8737 - val_loss: 1156.2437 - val_mean_squared_error: 1156.2437
# Epoch 35/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 604.5146 - mean_squared_error: 604.5146 - val_loss: 1161.2983 - val_mean_squared_error: 1161.2983
# Epoch 36/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 582.1872 - mean_squared_error: 582.1872 - val_loss: 1103.1803 - val_mean_squared_error: 1103.1803
# Epoch 37/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 576.9209 - mean_squared_error: 576.9209 - val_loss: 1400.7198 - val_mean_squared_error: 1400.7198
# Epoch 38/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 552.9532 - mean_squared_error: 552.9532 - val_loss: 1592.9726 - val_mean_squared_error: 1592.9726
# Epoch 39/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 541.4225 - mean_squared_error: 541.4225 - val_loss: 1301.2450 - val_mean_squared_error: 1301.2450
# Epoch 40/40
# 14849/14849 [==============================] - 16s 1ms/step - loss: 531.3725 - mean_squared_error: 531.3725 - val_loss: 1543.1456 - val_mean_squared_error: 1543.1456
# CPU times: user 13min 38s, sys: 1min 23s, total: 15min 2s
# Wall time: 10min 37s

# %%
plt.plot(hist.history['mean_squared_error'])
plt.plot(hist.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('Mean Squared Error')
plt.xlabel('# Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('MSE: {}'.format(scores[1]))
# Out:
# 15631/15631 [==============================] - 6s 380us/step
# MSE: 453.82220130582647

# %%
seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
seq_array_test_last.shape
# Out:
# (93, 50, 17)

# %%
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]

# %%
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
label_array_test_last.shape
# Out:
# (93, 1)

# %%
print(seq_array_test_last.shape)
print(label_array_test_last.shape)
# Out:
# (93, 50, 17)
# (93, 1)

# %%
# test metrics
scores_test = model.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
print('MSE: {}'.format(scores_test[1]))
# Out:
# MSE: 602.3475217101394

# %%
results_df = pd.DataFrame([[scores_test[1]],],
                         columns = ['MSE'],
                         index = ['LSTM'])
results_df
# Out:
#              MSE
# LSTM  602.347522

# %%
y_pred_test = model.predict(seq_array_test_last, verbose=0)

import matplotlib.pyplot as plt2

plt2.plot(y_pred_test, color='red', label='Prediction')
plt2.plot(label_array_test_last, color='blue', label='Ground Truth')
plt2.legend(loc='upper left')
plt2.show()
